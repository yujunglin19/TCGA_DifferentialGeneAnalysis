# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot
import statistics as stats
import math

# %%
data = pd.read_csv("GBM_totaldata.csv")

# %%
IL13RA1 = data.get("IL13RA1")
IL13RA2 = data.get("IL13RA2")
IL4R = data.get("IL4R")
IL4 = data.get("IL4")
NOTCH1 = data.get("NOTCH1")
TOP2A = data.get("TOP2A")

IL13RA1_log = np.log10(data.get("IL13RA1"))
IL13RA2_log = np.log(data.get("IL13RA2"))
IL4R_log = np.log(data.get("IL4R"))

IL4R.to_csv('out3.csv')

# %%
mean_IL4R = round(stats.mean(IL4R),3)
mean_IL4 = round(stats.mean(IL4),3)
mean_IL13RA1 = round(stats.mean(IL13RA1),3)
mean_IL13RA2 = round(stats.mean(IL13RA2),3)
mean_NOTCH1 = round(stats.mean(NOTCH1),3)
mean_TOP2A = round(stats.mean(TOP2A),3)
print("IL13RA1 mean", mean_IL13RA1)
print("IL13RA2 mean", mean_IL13RA2)
print("IL4 mean", mean_IL4)
print("IL4R mean", mean_IL4R )
print("NOTCH1 mean", mean_NOTCH1)
print("TOP2A mean", mean_TOP2A)
# Out:
# IL13RA1 mean 23.609
# IL13RA2 mean 18.303
# IL4 mean 0.104
# IL4R mean 5.816
# NOTCH1 mean 16.564
# TOP2A mean 20.259

# %%
matplotlib.pyplot.scatter(IL13RA1,IL13RA2)
y = np.corrcoef(IL13RA1,IL13RA2)
print(y)
# Out:
# [[1.         0.21774994]
#  [0.21774994 1.        ]]

# %%
matplotlib.pyplot.scatter(IL4R,IL13RA2)
y = np.corrcoef(IL4R,IL13RA2)
print(y)
# Out:
# [[1.         0.03562624]
#  [0.03562624 1.        ]]

# %%
matplotlib.pyplot.scatter(IL13RA1,IL4R)
y = np.corrcoef(IL4R,IL13RA1)
print(y)
# Out:
# [[1.         0.67149274]
#  [0.67149274 1.        ]]
